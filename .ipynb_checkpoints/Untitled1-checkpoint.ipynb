# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set(style="whitegrid")

import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
lap_times = pd.read_csv(r"F1_data\lap_times.csv")
races = pd.read_csv(r"F1_data\races.csv")
circuits = pd.read_csv(r"F1_data\circuits.csv")
drivers = pd.read_csv(r"F1_data\drivers.csv")
constructors = pd.read_csv(r"F1_data\constructors.csv")
results = pd.read_csv(r"F1_data\results.csv")

# %%
laps = races[['raceId', 'year', 'round', 'name']].merge(right=lap_times, on='raceId', how='outer')
laps = laps.merge(right=drivers[['driverId', 'code', 'dob', 'nationality']], on='driverId', how='outer')
laps.columns = ['raceId', 'year', 'round', 'name', 'driverId', 'lap', 'position_lap', 'time', 'milliseconds', 'code', 'dob', 'nationality_driver']

teams = results[['raceId', 'driverId', 'constructorId', 'position']].merge(right=constructors[['constructorId', 'constructorRef', 'nationality']],
                                                      on='constructorId', how='outer')
teams.columns = ['raceId', 'driverId', 'constructorId', 'position_race', 'constructorRef', 'nationality_constructor']

# %%
df = laps.merge(right=teams, on=['raceId', 'driverId'], how='outer')
df.head()
# Out:
#    raceId    year  round                   name  driverId  lap  position_lap  \
# 0     1.0  2009.0    1.0  Australian Grand Prix       1.0  1.0          13.0
# 1     1.0  2009.0    1.0  Australian Grand Prix       1.0  2.0          12.0
# 2     1.0  2009.0    1.0  Australian Grand Prix       1.0  3.0          11.0
# 3     1.0  2009.0    1.0  Australian Grand Prix       1.0  4.0          10.0
# 4     1.0  2009.0    1.0  Australian Grand Prix       1.0  5.0          10.0
#
#        time  milliseconds code         dob nationality_driver  constructorId  \
# 0  1:49.088      109088.0  HAM  1985-01-07            British            1.0
# 1  1:33.740       93740.0  HAM  1985-01-07            British            1.0
# 2  1:31.600       91600.0  HAM  1985-01-07            British            1.0
# 3  1:31.067       91067.0  HAM  1985-01-07            British            1.0
# 4  1:32.129       92129.0  HAM  1985-01-07            British            1.0
#
#   position_race constructorRef nationality_constructor
# 0            \N        mclaren                 British
# 1            \N        mclaren                 British
# 2            \N        mclaren                 British
# 3            \N        mclaren                 British
# 4            \N        mclaren                 British

# %%
winners = df[df.position_race == "1"]

# %% [markdown]
# * Average race speed of winner over time by race, get which races have stayed the same, consistent?
# * Fasest race on average

# %%
df.columns
# Out:
# Index(['raceId', 'year', 'round', 'name', 'driverId', 'lap', 'position_lap',
#        'time', 'milliseconds', 'code', 'dob', 'nationality_driver',
#        'constructorId', 'position_race', 'constructorRef',
#        'nationality_constructor'],
#       dtype='object')

# %%
avg_speed = pd.DataFrame({'avg_speed' : winners.groupby(['raceId', 'year', 'name'])['milliseconds'].mean()}).reset_index()
avg_speed.head()
# Out:
#    raceId    year                   name      avg_speed
# 0     1.0  2009.0  Australian Grand Prix   97513.517241
# 1     2.0  2009.0   Malaysian Grand Prix  107439.419355
# 2     3.0  2009.0     Chinese Grand Prix  126133.660714
# 3     4.0  2009.0     Bahrain Grand Prix   96634.771930
# 4     5.0  2009.0     Spanish Grand Prix   88472.757576

# %%
fig = plt.figure(figsize=(15,15))
for key, grp in avg_speed.groupby(['name']): 
    plt.plot(grp['year'], grp['avg_speed'], label = key)
plt.legend(loc='best')    
plt.show()
