# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

sns.set(style="whitegrid")

import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# #### Import data

# %%
lap_times = pd.read_csv(r"F1_data\lap_times.csv")
drivers = pd.read_csv(r"F1_data\drivers.csv")
constructors = pd.read_csv(r"F1_data\constructors.csv")
results = pd.read_csv(r"F1_data\results.csv")

circuits = pd.read_csv(r"data_cleaned\circuits.csv")
races = pd.read_csv(r"data_cleaned\races.csv")

# %% [markdown]
# #### Get lap speeds in terms of km/sec and km/min (lap speeds are only recorded since 1996)

# %%
lap_speeds = races[['raceId', 'length_val']]\
            .merge(right=lap_times[['raceId', 'driverId', 'lap', 'position', 'milliseconds']], on='raceId', how='outer')

lap_speeds['km_per_sec'] = lap_speeds['length_val']/(lap_speeds['milliseconds']*0.001)
lap_speeds['km_per_min'] = lap_speeds['length_val']/((lap_speeds['milliseconds']*0.001)/60)

lap_speeds.dropna(axis=0, inplace=True)
lap_speeds.head()
# Out:
#    raceId  length_val  driverId  lap  position  milliseconds  km_per_sec  \
# 0  1       5.303       1.0       1.0  13.0      109088.0      0.048612
# 1  1       5.303       1.0       2.0  12.0      93740.0       0.056571
# 2  1       5.303       1.0       3.0  11.0      91600.0       0.057893
# 3  1       5.303       1.0       4.0  10.0      91067.0       0.058232
# 4  1       5.303       1.0       5.0  10.0      92129.0       0.057561
#
#    km_per_min
# 0  2.916728
# 1  3.394282
# 2  3.473581
# 3  3.493911
# 4  3.453636

# %% [markdown]
# #### Get driver and constructor combinations by race

# %%
teams = results[['raceId', 'driverId', 'constructorId', 'position']]\
        .merge(right=constructors[['constructorId', 'constructorRef']], on='constructorId', how='outer')
teams.columns = ['raceId', 'driverId', 'constructorId', 'position_race', 'constructorRef']

# %%
constructor_map = {'alfa': ['sauber', 'bmw_sauber', 'alfa'],
                   'alphatauri': ['alpha_tauri', 'minardi', 'toro_rosso', 'alphatauri'],
                   'mclaren': ['mclaren', 'mclaren-alfa_romeo', 'mclaren-brm', 'mclaren-ford', 'mclaren-seren'],
                   'mercedes': ['mercedes', 'tyrrell', 'bar', 'brawn', 'honda'],
                   'racing_point': ['racing_point', 'force_india', 'jordan', 'spyker', 'spyker_mf1', 'mf1'],
                   'red_bull': ['red_bull', 'stewart', 'jaguar'],
                   'renault': ['renault', 'toleman', 'benetton', 'lotus_racing', 'lotus_f1'],
                   'ferrari': ['ferrari'],
                   'haas': ['haas'],
                   'williams': ['williams'],}

# reverse dictionary
reversed_constructor_map = {}
for k, v in constructor_map.items():
    for element in v:
        reversed_constructor_map[element] = k
        
teams["constructorRef_mapped"] = teams['constructorRef'].map(reversed_constructor_map)
teams.head()
# Out:
#    raceId  driverId  constructorId position_race constructorRef  \
# 0  18.0    1.0       1              1             mclaren
# 1  18.0    5.0       1              5             mclaren
# 2  19.0    5.0       1              3             mclaren
# 3  19.0    1.0       1              5             mclaren
# 4  20.0    5.0       1              5             mclaren
#
#   constructorRef_mapped
# 0  mclaren
# 1  mclaren
# 2  mclaren
# 3  mclaren
# 4  mclaren

# %%
        col_map = {'mercedes': 'mediumturquoise',
                  'red_bull': 'blue',
                  'racing_point': 'hotpink',
                  'mclaren': 'darkorange',
                  'renault': 'gold',
                  'ferrari': 'red',
                  'alphatauri': 'black',
                  'alfa': 'darkred',
                  'haas': 'darkgrey',
                  'williams': 'dodgerblue'}

# %%
races.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0  1       2009  1      1          Australian Grand Prix  2009-03-29
# 1  2       2009  2      2          Malaysian Grand Prix   2009-04-05
# 2  3       2009  3      17         Chinese Grand Prix     2009-04-19
# 3  4       2009  4      3          Bahrain Grand Prix     2009-04-26
# 4  5       2009  5      4          Spanish Grand Prix     2009-05-10
#
#        time                                                      url  length  \
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_Grand_Prix  5.303
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Grand_Prix   5.543
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Grand_Prix     5.451
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Grand_Prix     5.412
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Grand_Prix     4.655
#
#    length_val length_cleaned
# 0  5.303       5.303
# 1  5.543       5.543
# 2  5.451       5.451
# 3  5.412       5.412
# 4  4.655       4.655

# %%
df=lap_speeds.merge(races[['date','year', 'raceId', 'circuitId']], on ='raceId', how='left')
df=df.merge(teams[['raceId', 'driverId', 'constructorRef', 'constructorRef_mapped']], on=['raceId', 'driverId'], how='left')
df=df.merge(circuits[['circuitId', 'circuitRef']], on='circuitId', how='left')
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#    raceId  length_val  driverId  lap  position  milliseconds  km_per_sec  \
# 0  1       5.303       1.0       1.0  13.0      109088.0      0.048612
# 1  1       5.303       1.0       2.0  12.0      93740.0       0.056571
# 2  1       5.303       1.0       3.0  11.0      91600.0       0.057893
# 3  1       5.303       1.0       4.0  10.0      91067.0       0.058232
# 4  1       5.303       1.0       5.0  10.0      92129.0       0.057561
#
#    km_per_min       date  year  circuitId constructorRef  \
# 0  2.916728   2009-03-29  2009  1          mclaren
# 1  3.394282   2009-03-29  2009  1          mclaren
# 2  3.473581   2009-03-29  2009  1          mclaren
# 3  3.493911   2009-03-29  2009  1          mclaren
# 4  3.453636   2009-03-29  2009  1          mclaren
#
#   constructorRef_mapped   circuitRef
# 0  mclaren               albert_park
# 1  mclaren               albert_park
# 2  mclaren               albert_park
# 3  mclaren               albert_park
# 4  mclaren               albert_park

# %%
avg_lap_speed = pd.DataFrame({'avg_lap_speed' : df.groupby(['raceId', 'year', 'circuitRef'])['km_per_min']
              .mean()}).sort_values(['circuitRef', 'year']).reset_index()

# %%
fig = plt.figure(figsize=(15,15))
for key, grp in avg_lap_speed.groupby(['circuitRef']):
    plt.plot(grp['year'], grp['avg_lap_speed'], label = key)
plt.legend(loc='best')    
plt.show()

# %%
avg_lap_speed = pd.DataFrame({'avg_lap_speed' : df.groupby(['year', 'constructorRef_mapped'])['km_per_min']
              .mean()}).sort_values(['constructorRef_mapped', 'year']).reset_index()
avg_lap_speed = avg_lap_speed.sort_values(["constructorRef_mapped","year"])

# %%
avg_lap_speed
# Out:
#      year constructorRef_mapped  avg_lap_speed
# 0    1996  alfa                  2.961613
# 1    1997  alfa                  3.203475
# 2    1998  alfa                  3.095327
# 3    1999  alfa                  3.181770
# 4    2000  alfa                  3.181504
# 5    2001  alfa                  3.287922
# 6    2002  alfa                  3.242093
# 7    2003  alfa                  3.264992
# 8    2004  alfa                  3.415060
# 9    2005  alfa                  3.336416
# 10   2006  alfa                  3.271604
# 199  2016  renault               3.105674
# 200  2017  renault               3.243240
# 201  2018  renault               3.256631
# 202  2019  renault               3.290551
# 203  2020  renault               3.458589
# 204  1996  williams              3.082865
# 205  1997  williams              3.242209
# 206  1998  williams              3.153851
# 207  1999  williams              3.147540
# 208  2000  williams              3.199229
# 209  2001  williams              3.344036
# 210  2002  williams              3.296861
# 211  2003  williams              3.297037
# 212  2004  williams              3.409894
# 213  2005  williams              3.333462
# 214  2006  williams              3.296073
# 215  2007  williams              3.252700
# 216  2008  williams              3.171079
# 217  2009  williams              3.209551
# 218  2010  williams              3.164311
# 219  2011  williams              3.046160
# 220  2012  williams              3.142204
# 221  2013  williams              3.127523
# 222  2014  williams              3.108113
# 223  2015  williams              3.136979
# 224  2016  williams              3.118291
# 225  2017  williams              3.241701
# 226  2018  williams              3.237236
# 227  2019  williams              3.228098
# 228  2020  williams              3.426114

# %%
constructor_names = {'alfa': 'Alfa Romeo',
                   'alphatauri': 'AlphaTauri',
                   'mclaren': 'McLaren',
                   'mercedes': 'Mercedes',
                   'racing_point': 'Racing Point',
                   'red_bull': 'Red Bull',
                   'renault': 'Renault',
                   'ferrari': 'Ferrari',
                   'haas': 'Haas',
                   'williams': 'Williams'}

col_map = {'mercedes': 'mediumturquoise',
          'red_bull': 'blue',
          'racing_point': 'hotpink',
          'mclaren': 'darkorange',
          'renault': 'gold',
          'ferrari': 'red',
          'alphatauri': 'black',
          'alfa': 'darkred',
          'haas': 'darkgrey',
          'williams': 'dodgerblue'}

line_map = {'mercedes': 'solid',
          'red_bull': 'solid',
          'racing_point': 'dashed',
          'mclaren': 'solid',
          'renault': 'solid',
          'ferrari': 'solid',
          'alphatauri': 'dotted',
          'alfa': 'dotted',
          'haas': 'dashed',
          'williams': 'dotted'}

col_map = {'mercedes': 'mediumturquoise',
          'red_bull': 'blue',
          'racing_point': 'mediumturquoise',
          'mclaren': 'darkorange',
          'renault': 'gold',
          'ferrari': 'red',
          'alphatauri': 'blue',
          'alfa': 'red',
          'haas': 'red',
          'williams': 'mediumturquoise'}

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

sns.set(style="whitegrid")
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
#plt.rcParams['xtick.major.size'] = 20
plt.rcParams['xtick.major.width'] = 2
plt.rcParams['ytick.major.width'] = 2
plt.rcParams['xtick.bottom'] = True
plt.rcParams['ytick.left'] = True

years = avg_lap_speed['year'].unique()

fig = plt.figure(figsize=(15,10))

ax1 = plt.gca()
ax1.set_xlim(1995,2021)
ax1.set_ylim(2.9,3.58)

for key, grp in avg_lap_speed.groupby(['constructorRef_mapped']):
    ax1.plot(grp['year'], grp['avg_lap_speed'], label = constructor_names[key], 
             color=col_map[key], linestyle = line_map[key])

plt.xticks(np.arange(min(years), max(years)+1, 2.0))

leg = ax1.legend(loc='center left', bbox_to_anchor=(1, .8), fontsize=15)

leg.set_title('Constructors', prop = {'size':'x-large'})
leg.get_frame().set_linewidth(0.0)
leg._legend_box.sep = 20

for legobj in leg.legendHandles:
    legobj.set_linewidth(4.0)

ax1.axvspan(1996, 2005, facecolor='azure', alpha=0.5)
ax1.axvspan(2005, 2013, facecolor='cornsilk', alpha=0.5)
ax1.axvspan(2013, 2020, facecolor='honeydew', alpha=0.5)

ax1.annotate('', xy=(1996, 3.53), xytext=(2005, 3.53), xycoords='data', textcoords='data',
             arrowprops=dict(arrowstyle= '|-|', color='teal', lw=2, ls='--'))
ax1.annotate('V10/12 Engines', xy=(2000.5, 3.54), ha='center', va='center', color = 'teal', fontsize=16)

ax1.annotate('', xy=(2005, 3.53), xytext=(2013, 3.53), xycoords='data', textcoords='data',
             arrowprops=dict(arrowstyle= '|-|', color='darkgoldenrod', lw=2, ls='--'))
ax1.annotate('V8 Engines', xy=(2009, 3.54), ha='center', va='center', color='darkgoldenrod', fontsize=16)

ax1.annotate('', xy=(2013, 3.53), xytext=(2020, 3.53), xycoords='data', textcoords='data',
             arrowprops=dict(arrowstyle= '|-|', color='darkgreen', lw=2, ls='--'))
ax1.annotate('V6 - Hybrid Engines', xy=(2016.5, 3.54), ha='center', va='center', color='darkgreen', fontsize=16)

plt.title("Average Yearly Km/min by Constructor", fontsize=20, fontweight='bold', pad=20)
plt.xlabel("Year", fontsize=18, fontweight='bold', labelpad=20)
plt.ylabel("Km/min", fontsize=18, fontweight='bold', labelpad=20)

for tick in ax1.xaxis.get_major_ticks():
    tick.label1.set_fontsize(15)
    tick.label1.set_fontweight('bold')
for tick in ax1.yaxis.get_major_ticks():
    tick.label1.set_fontsize(15)
    tick.label1.set_fontweight('bold')

plt.setp(ax1.spines.values(), linewidth=3, color='black')

ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

plt.savefig(r"figs\avgLapYear_V2.png", bbox_inches='tight')

plt.show()

# %%
years
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-258-e1775723e48f> in <module>
# ----> 1 years
#
# NameError: name 'years' is not defined

# %%
engines = pd.read_csv(r"data_cleaned\engines.csv")
engines.loc[engines['engine'] == 'toro rosso', 'engine'] = 'renault'
engines.loc[engines['engine'] == 'bwt mercedes', 'engine'] = 'mercedes'
engines.loc[engines['engine'] == 'bmw sauber', 'engine'] = 'bmw'

engines.sort_values(['constructorRef', 'year'])
# Out:
#      year     constructor_name      engine  constructorId          name  \
# 7    1995  sauber               ford        51.0           alfa romeo
# 13   1996  sauber               ford        51.0           alfa romeo
# 21   1997  sauber               petronas    51.0           alfa romeo
# 30   1998  sauber               petronas    51.0           alfa romeo
# 39   1999  sauber               petronas    51.0           alfa romeo
# 49   2000  sauber               petronas    51.0           alfa romeo
# 58   2001  sauber               petronas    51.0           alfa romeo
# 64   2002  sauber               petronas    51.0           alfa romeo
# 74   2003  sauber               petronas    51.0           alfa romeo
# 84   2005  sauber               petronas    51.0           alfa romeo
# 94   2006  bmw sauber           bmw         51.0           alfa romeo
# 101  2007  bmw sauber           bmw         51.0           alfa romeo
# 107  2008  bmw sauber           bmw         51.0           alfa romeo
# 117  2009  bmw sauber           bmw         51.0           alfa romeo
# 133  2010  bmw sauber           ferrari     51.0           alfa romeo
# 141  2011  sauber               ferrari     51.0           alfa romeo
# 150  2012  sauber               ferrari     51.0           alfa romeo
# 158  2013  sauber               ferrari     51.0           alfa romeo
# 167  2014  sauber               ferrari     51.0           alfa romeo
# 176  2015  sauber               ferrari     51.0           alfa romeo
# 186  2016  sauber               ferrari     51.0           alfa romeo
# 121  2009  williams             toyota      3.0            williams
# 128  2010  williams             cosworth    3.0            williams
# 139  2011  williams             cosworth    3.0            williams
# 152  2012  williams             renault     3.0            williams
# 160  2013  williams             renault     3.0            williams
# 169  2014  williams             mercedes    3.0            williams
# 178  2015  williams             mercedes    3.0            williams
# 188  2016  williams             mercedes    3.0            williams
# 198  2017  williams             mercedes    3.0            williams
# 208  2018  williams             mercedes    3.0            williams
# 218  2019  williams             mercedes    3.0            williams
# 228  2020  williams             mercedes    3.0            williams
#
#     constructorRef
# 7    alfa
# 13   alfa
# 21   alfa
# 30   alfa
# 39   alfa
# 49   alfa
# 58   alfa
# 64   alfa
# 74   alfa
# 84   alfa
# 94   alfa
# 101  alfa
# 107  alfa
# 117  alfa
# 133  alfa
# 141  alfa
# 150  alfa
# 158  alfa
# 167  alfa
# 176  alfa
# 186  alfa
# 196  alfa
# 206  alfa
# 209  alfa
# 219  alfa
# 5    alphatauri
# 15   alphatauri
# 23   alphatauri
# 33   alphatauri
# 41   alphatauri
# 50   alphatauri
# 60   alphatauri
# 69   alphatauri
# 78   alphatauri
# 87   alphatauri
# 96   alphatauri
# 104  alphatauri
# 111  alphatauri
# 119  alphatauri
# 131  alphatauri
# 142  alphatauri
# 151  alphatauri
# 161  alphatauri
# 168  alphatauri
# 177  alphatauri
# 187  alphatauri
# 197  alphatauri
# 207  alphatauri
# 217  alphatauri
# 220  alphatauri
# 6    ferrari
# 8    ferrari
# 17   ferrari
# 26   ferrari
# 35   ferrari
# 44   ferrari
# 52   ferrari
# 61   ferrari
# 70   ferrari
# 79   ferrari
# 90   ferrari
# 99   ferrari
# 106  ferrari
# 116  ferrari
# 127  ferrari
# 136  ferrari
# 146  ferrari
# 154  ferrari
# 162  ferrari
# 170  ferrari
# 179  ferrari
# 189  ferrari
# 199  ferrari
# 210  ferrari
# 221  ferrari
# 181  haas
# 191  haas
# 201  haas
# 211  haas
# 222  haas
# 3    mclaren
# 11   mclaren
# 19   mclaren
# 28   mclaren
# 34   mclaren
# 43   mclaren
# 53   mclaren
# 62   mclaren
# 72   mclaren
# 83   mclaren
# 89   mclaren
# 97   mclaren
# 114  mclaren
# 115  mclaren
# 124  mclaren
# 135  mclaren
# 145  mclaren
# 155  mclaren
# 164  mclaren
# 173  mclaren
# 182  mclaren
# 192  mclaren
# 202  mclaren
# 212  mclaren
# 223  mclaren
# 1    mercedes
# 14   mercedes
# 22   mercedes
# 32   mercedes
# 42   mercedes
# 51   mercedes
# 56   mercedes
# 66   mercedes
# 77   mercedes
# 80   mercedes
# 92   mercedes
# 100  mercedes
# 112  mercedes
# 123  mercedes
# 125  mercedes
# 137  mercedes
# 147  mercedes
# 157  mercedes
# 165  mercedes
# 174  mercedes
# 183  mercedes
# 193  mercedes
# 203  mercedes
# 213  mercedes
# 224  mercedes
# 4    racing_point
# 12   racing_point
# 20   racing_point
# 29   racing_point
# 37   racing_point
# 45   racing_point
# 57   racing_point
# 65   racing_point
# 75   racing_point
# 86   racing_point
# 95   racing_point
# 105  racing_point
# 113  racing_point
# 122  racing_point
# 130  racing_point
# 140  racing_point
# 149  racing_point
# 159  racing_point
# 171  racing_point
# 180  racing_point
# 190  racing_point
# 200  racing_point
# 214  racing_point
# 225  racing_point
# 24   red_bull
# 31   red_bull
# 40   red_bull
# 46   red_bull
# 59   red_bull
# 68   red_bull
# 76   red_bull
# 85   red_bull
# 93   red_bull
# 102  red_bull
# 110  red_bull
# 120  red_bull
# 126  red_bull
# 134  red_bull
# 144  red_bull
# 153  red_bull
# 166  red_bull
# 175  red_bull
# 184  red_bull
# 194  red_bull
# 204  red_bull
# 215  red_bull
# 226  red_bull
# 0    renault
# 9    renault
# 18   renault
# 27   renault
# 38   renault
# 48   renault
# 55   renault
# 67   renault
# 73   renault
# 81   renault
# 88   renault
# 98   renault
# 108  renault
# 118  renault
# 129  renault
# 132  renault
# 138  renault
# 143  renault
# 148  renault
# 156  renault
# 163  renault
# 172  renault
# 185  renault
# 195  renault
# 205  renault
# 216  renault
# 227  renault
# 2    williams
# 10   williams
# 16   williams
# 25   williams
# 36   williams
# 47   williams
# 54   williams
# 63   williams
# 71   williams
# 82   williams
# 91   williams
# 103  williams
# 109  williams
# 121  williams
# 128  williams
# 139  williams
# 152  williams
# 160  williams
# 169  williams
# 178  williams
# 188  williams
# 198  williams
# 208  williams
# 218  williams
# 228  williams

# %%
df2 = df.merge(engines[['year', 'engine', 'constructorRef']], left_on=['year', 'constructorRef_mapped'], 
              right_on=['year', 'constructorRef'], how='left')
df2.head()
# Out:
#    raceId  length_val  driverId  lap  position  milliseconds  km_per_sec  \
# 0  1       5.303       1.0       1.0  13.0      109088.0      0.048612
# 1  1       5.303       1.0       2.0  12.0      93740.0       0.056571
# 2  1       5.303       1.0       3.0  11.0      91600.0       0.057893
# 3  1       5.303       1.0       4.0  10.0      91067.0       0.058232
# 4  1       5.303       1.0       5.0  10.0      92129.0       0.057561
#
#    km_per_min  year  circuitId constructorRef_x constructorRef_mapped  \
# 0  2.916728    2009  1          mclaren          mclaren
# 1  3.394282    2009  1          mclaren          mclaren
# 2  3.473581    2009  1          mclaren          mclaren
# 3  3.493911    2009  1          mclaren          mclaren
# 4  3.453636    2009  1          mclaren          mclaren
#
#     circuitRef engine_x  engine_y constructorRef_y
# 0  albert_park  V8       mercedes  mclaren
# 1  albert_park  V8       mercedes  mclaren
# 2  albert_park  V8       mercedes  mclaren
# 3  albert_park  V8       mercedes  mclaren
# 4  albert_park  V8       mercedes  mclaren

# %%
engine_count = pd.DataFrame({'engine_count' : engines.groupby(['engine', 'year'])['constructorId'].nunique()}).reset_index()
engine_count.sort_values(['year', 'engine_count'])
# Out:
#          engine  year  engine_count
# 19   ferrari     1995  1
# 67   mercedes    1995  1
# 103  peugeot     1995  1
# 140  yamaha      1995  1
# 45   ford        1995  2
# 109  renault     1995  2
# 20   ferrari     1996  1
# 68   mercedes    1996  1
# 104  peugeot     1996  1
# 141  yamaha      1996  1
# 46   ford        1996  2
# 110  renault     1996  2
# 21   ferrari     1997  1
# 51   hart        1997  1
# 69   mercedes    1997  1
# 95   petronas    1997  1
# 105  peugeot     1997  1
# 47   ford        1997  2
# 111  renault     1997  2
# 22   ferrari     1998  1
# 66   mecachrome  1998  1
# %%
avg_lap_speed = pd.DataFrame({'avg_lap_speed' : df2.groupby(['year', 'engine_y'])['km_per_min']
              .max()}).sort_values(['engine_y', 'year']).reset_index()
avg_lap_speed = avg_lap_speed.sort_values(["engine_y","year"])

fig = plt.figure(figsize=(15,15))
for key, grp in avg_lap_speed.groupby(['engine_y']):
    plt.plot(grp['year'], grp['avg_lap_speed'], label = key)
plt.legend(loc='best')    
plt.show()

# %%
avg_lap_speed

for key, grp in avg_lap_speed.groupby(['engine_y']):
    print(key)
    print(grp)
# Out:
# asiatech
#    year  engine_y  avg_lap_speed
# 0  2002  asiatech  3.990402
# bmw
#    year engine_y  avg_lap_speed
# 1  2000  bmw      4.011958
# 2  2001  bmw      4.085668
# 3  2002  bmw      4.084659
# 4  2003  bmw      4.232277
# 5  2005  bmw      4.194280
# 6  2006  bmw      4.182118
# 7  2007  bmw      4.153631
# 8  2008  bmw      3.870300
# 9  2009  bmw      4.065834
# cosworth
#     year  engine_y  avg_lap_speed
# 10  2000  cosworth  3.814147
# 11  2001  cosworth  4.023802
# 12  2002  cosworth  4.061510
# 13  2003  cosworth  4.148822
# 14  2005  cosworth  4.156015
# 15  2006  cosworth  4.128176
# 16  2010  cosworth  4.110454
# 17  2011  cosworth  3.932924
# european
#     year  engine_y  avg_lap_speed
# 18  2001  european  3.962877
# ferrari
#     year engine_y  avg_lap_speed
# 19  1996  ferrari  4.020439
# 20  1997  ferrari  4.041796
# 21  1998  ferrari  4.049928
# 22  1999  ferrari  4.042976
# 23  2000  ferrari  4.057528
# 24  2001  ferrari  4.078572
# 25  2002  ferrari  4.154823
# 26  2003  ferrari  4.247483
# 27  2005  ferrari  4.164330
# 28  2006  ferrari  4.209264
# 29  2007  ferrari  4.169126
# 30  2008  ferrari  3.947664
# 31  2009  ferrari  4.100707
# 32  2010  ferrari  4.131021
# 33  2011  ferrari  3.998666
# 34  2012  ferrari  3.969530
# 35  2013  ferrari  4.008257
# 36  2014  ferrari  3.907940
# 37  2015  ferrari  3.977980
# 38  2016  ferrari  4.040876
# 39  2017  ferrari  4.142937
# 40  2018  ferrari  4.212836
# 41  2019  ferrari  4.197877
# 42  2020  ferrari  4.099546
# fondmetal
#     year   engine_y  avg_lap_speed
# 43  2000  fondmetal  3.943902
# ford
#     year engine_y  avg_lap_speed
# 44  1996  ford     3.924147
# 45  1997  ford     3.958969
# 46  1998  ford     3.946378
# 47  1999  ford     4.033790
# 48  2003  ford     4.082788
# hart
#     year engine_y  avg_lap_speed
# 49  1997  hart     3.884824
# honda
#     year engine_y  avg_lap_speed
# 50  2000  honda    4.021381
# 51  2001  honda    4.024547
# 52  2002  honda    4.078859
# 53  2003  honda    4.185744
# 54  2005  honda    4.179603
# 55  2006  honda    4.161738
# 56  2007  honda    4.111816
# 57  2008  honda    3.869438
# 58  2015  honda    3.892927
# 59  2016  honda    4.072885
# 60  2017  honda    4.047699
# 61  2018  honda    4.100416
# 62  2019  honda    4.180508
# 63  2020  honda    4.136035
# mecachrome
#     year    engine_y  avg_lap_speed
# 64  1998  mecachrome  4.003284
# mercedes
#     year  engine_y  avg_lap_speed
# 65  1996  mercedes  3.987239
# 66  1997  mercedes  4.082162
# 67  1998  mercedes  4.066292
# 68  1999  mercedes  4.033461
# 69  2000  mercedes  4.060751
# 70  2001  mercedes  3.980395
# 71  2002  mercedes  4.091005
# 72  2003  mercedes  4.237127
# 73  2005  mercedes  4.264576
# 74  2006  mercedes  4.210080
# 75  2007  mercedes  4.194230
# 76  2008  mercedes  3.886253
# 77  2009  mercedes  4.101771
# 78  2010  mercedes  4.113811
# 79  2011  mercedes  4.032859
# 80  2012  mercedes  3.984227
# 81  2013  mercedes  4.048737
# 82  2014  mercedes  3.949593
# 83  2015  mercedes  4.010292
# 84  2016  mercedes  4.027438
# 85  2017  mercedes  4.163233
# 86  2018  mercedes  4.213244
# 87  2019  mercedes  4.250235
# 88  2020  mercedes  4.200566
# mugen
#     year engine_y  avg_lap_speed
# 89  1998  mugen    4.016521
# 90  1999  mugen    4.029470
# 91  2000  mugen    3.913243
# petronas
#     year  engine_y  avg_lap_speed
# 92  1997  petronas  3.998984
# 93  1998  petronas  3.986642
# 94  1999  petronas  4.029752
# 95  2000  petronas  3.985324
# 96  2001  petronas  4.011032
# 97  2002  petronas  4.047888
# 98  2003  petronas  4.161738
# 99  2005  petronas  4.169376
# peugeot
#      year engine_y  avg_lap_speed
# 100  1996  peugeot  3.953996
# 101  1997  peugeot  4.029846
# playlife
#      year  engine_y  avg_lap_speed
# 102  1998  playlife  3.994969
# 103  1999  playlife  3.919038
# 104  2000  playlife  4.007564
# renault
#      year engine_y  avg_lap_speed
# 105  1996  renault  3.995292
# 106  1997  renault  4.044393
# 107  2001  renault  3.982219
# 108  2002  renault  4.071549
# 109  2003  renault  4.177895
# 110  2005  renault  4.231247
# 111  2006  renault  4.181615
# 112  2007  renault  4.126754
# 113  2008  renault  3.875737
# 114  2009  renault  4.079865
# 115  2010  renault  4.124208
# 116  2011  renault  4.015620
# 117  2012  renault  3.947395
# 118  2013  renault  4.009459
# 119  2014  renault  3.928079
# 120  2015  renault  3.977343
# 121  2016  renault  3.966993
# 122  2017  renault  4.053317
# 123  2018  renault  4.135100
# 124  2019  renault  4.164330
# 125  2020  renault  4.143678
# supertec
#      year  engine_y  avg_lap_speed
# 126  1999  supertec  4.045385
# tag heuer
#      year   engine_y  avg_lap_speed
# 127  2016  tag heuer  4.045438
# 128  2017  tag heuer  4.169576
# 129  2018  tag heuer  4.157208
# toyota
#      year engine_y  avg_lap_speed
# 130  2005  toyota   4.098337
# 131  2006  toyota   4.097758
# 132  2007  toyota   4.114736
# 133  2008  toyota   3.861185
# 134  2009  toyota   4.046286
# yamaha
#      year engine_y  avg_lap_speed
# 135  1996  yamaha   3.890762

# %%
fastest_lap_speed = pd.DataFrame({'fastest_lap_speed' : df.groupby(['year', 'constructorRef', 'constructorRef_mapped'])['km_per_min']
              .max()}).sort_values(['constructorRef', 'year']).reset_index()
fastest_lap_speed = fastest_lap_speed.sort_values(["constructorRef_mapped","year"])

fig = plt.figure(figsize=(15,15))
for key, grp in fastest_lap_speed.groupby(['constructorRef_mapped']):
    plt.plot(grp['year'], grp['fastest_lap_speed'], label = key)
plt.legend(loc='best')    
plt.show()
