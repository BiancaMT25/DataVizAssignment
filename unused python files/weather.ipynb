# %%
s

# %%
weather = pd.read_csv("output.csv")
weather.head()
# Out:
#    raceId                 date      lat      lng  temp  precip  wspd  \
# 0    1044  2020-11-15T00:00:00  40.9517  29.4050  11.8     0.0  14.5
# 1    1043  2020-11-01T00:00:00  44.3439  11.7167  12.6     0.0   9.4
# 2    1042  2020-10-25T00:00:00  37.2270  -8.6267  16.9     2.1  26.0
# 3    1041  2020-10-11T00:00:00  50.3356   6.9475   7.3     0.0  15.2
# 4    1040  2020-09-27T00:00:00  43.4057  39.9578  23.2     0.0  21.6
#
#    visibility        conditions
# 0        10.0          Overcast
# 1         4.6  Partially cloudy
# 2        10.0              Rain
# 3        19.3             Clear
# 4        10.0             Clear

# %%
f, ax = plt.subplots(figsize = (15,6))

sns.set_color_codes("pastel")

sns.barplot(y="conditions",x="raceId", data=weather,
            label="Total", color="b")

plt.show()

# %%
weather.iloc[:,4:8].hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002AB53C22198>,
# ...
#       dtype=object)

# %%
weather2 = pd.read_csv("weather_2.csv")
weather2.head()
# Out:
#    raceId                                                url  \
# 0       1  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1       2  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2       3  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3       4  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4       5  http://en.wikipedia.org/wiki/2009_Spanish_Gran...
#
#                                              weather  weather_warm  \
# 0  Sunny with temperatures reaching up to 27ʡC (...             1
# 1  Dry start, with heavy rain and thunderstorm/mo...             0
# 2                                               Rain             0
# 3                                              Sunny             1
# 4                                        Warm, Sunny             1
#
#    weather_cold  weather_dry  weather_wet  weather_cloudy
# 0             0            0            0               0
# 1             0            1            1               0
# ...

# %%
#f, ax = plt.subplots(figsize = (15,6))

#sns.set_color_codes("pastel")

weather2.iloc[:,3:].sum().plot.bar()

#plt.show()

# %%
merged_weather = weather.merge(right=weather2, on='raceId', how='outer')
merged_weather
# Out:
#       raceId                 date       lat        lng  temp  precip  wspd  \
# 0       1044  2020-11-15T00:00:00  40.95170   29.40500  11.8    0.00  14.5
# 1       1043  2020-11-01T00:00:00  44.34390   11.71670  12.6    0.00   9.4
# 2       1042  2020-10-25T00:00:00  37.22700   -8.62670  16.9    2.10  26.0
# 3       1041  2020-10-11T00:00:00  50.33560    6.94750   7.3    0.00  15.2
# 4       1040  2020-09-27T00:00:00  43.40570   39.95780  23.2    0.00  21.6
# 5       1039  2020-09-13T00:00:00  43.99750   11.37190  26.4    0.00  19.2
# 6       1038  2020-09-06T00:00:00  45.61560    9.28111  22.9    0.00  11.2
# 7       1037  2020-08-30T00:00:00  50.43720    5.97139  12.0   17.32  14.5
# 8       1036  2020-08-16T00:00:00  41.57000    2.26111  25.2    0.00  20.3
# 9       1035  2020-08-09T00:00:00  52.07860   -1.01694  19.5    0.00  22.2
# 10      1034  2020-08-02T00:00:00  52.07860   -1.01694  16.6    0.00  21.3
# ...

# %%
print(weather2.shape)
print(weather.shape)
print(merged_weather.shape)
# Out:
# (1035, 8)
# (1032, 9)
# (1035, 16)

# %%
group = merged_weather[['visibility', 'weather_wet']].groupby(["weather_wet"])
group.hist()
# Out:
# weather_wet
# 0    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# 1    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# dtype: object
